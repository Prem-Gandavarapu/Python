# %%
import math
n = int(input())
print(int(math.log10(n) + 1))
# Out:
# 1

# %%
n = int(input())
revNum = 0
while n > 0:
    revNum = revNum * 10 + n % 10
    n = n // 10
    
print(revNum)
# Out:
# 5

# %%
n = int(input())
revNum = 0
check = n
while n > 0:
    revNum = revNum * 10 + n % 10
    n = n // 10
    
print(check == revNum)
# Out:
# True

# %%
"""n1 = int(input())
n2 = int(input())

while n1 != 0 and n2 != 0:
    if n1 > n2:
        n1 = n1 - n2
    else:
        n2 = n2 - n1

if n1 == 0:
    print("GCD =", n2)
else:
    print("GCD =", n1)"""
    
n1 = int(input())
n2 = int(input())
LCM = n1 * n2
while n2 != 0:
    rem = n1 % n2
    n1 = n2
    n2 = rem

print("GCD =", n1)
print("LCM =",LCM//n1)
# Out:
# GCD = 5
# LCM = 60

# %%
def checkPrime(n):
    if n <= 1:
        return False
    for i in range(2, int(n**0.5) + 1):
        if n % i == 0:
            return False
    return True

n = int(input("Enter a number: "))

if checkPrime(n):
    print(n, "is a Prime Number")
else:
    print(n, "is Not a Prime Number")
# Out:
# 5 is a Prime Number

# %%
list = [x for x in range(10,0,-1)]
list.sort()
print(list[len(list) - 2])
# Out:
# 9

# %%
list1 = [1,4,2,3,5]
list2 = list1.sort()
print(list1 == list2)
# Out:
# False

# %%
k = int(input())

arr = [1,2,3,4,5]

k = k % len(arr)

arr = arr[k:] + arr[:k]

print(arr)

#left rotate to rotate right put -k inplace of k
# Out:
# [4, 5, 1, 2, 3]

# %%
arr = [1,3,4,5,6]
n = len(arr)
print(n)
# Out:
# 5

# %%
n = int(input())
x = 1
for i in range(2, n + 1):
    if n % i == 0:
        prime = True

        for j in range(2, int(i ** 0.5) + 1):
            if i % j == 0:
                prime = False
                break
            
        if prime:
            x = i

print(x)
# Out:
# 5
